# %% [markdown]
# <a href="https://colab.research.google.com/github/kholikulovelyor/DATA_SCIENCE_MOHIRDEV/blob/2-modul.-DATA-ANALYSIS-PANDAS-KUTUBXONASI/Web_sahifalardan_o'qish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
tashkent = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
len(tashkent)
# Out:
# 17

# %%
tashkent[5]
# Out:
#    Climate data for Tashkent (1981–2010, extremes 1881–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                                Average high °C (°F)
# 2                                  Daily mean °C (°F)
# 3                                 Average low °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6                          Average precipitation days
# 7                                  Average snowy days
# 8                       Average relative humidity (%)
# 9                         Mean monthly sunshine hours
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Jan
# 0                                          22.6(72.7)
# ...
